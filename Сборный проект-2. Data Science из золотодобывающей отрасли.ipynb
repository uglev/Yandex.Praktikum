# %% [markdown]
# Привет!
#
# Меня зовут Светлана Медведева и я буду проверять Твою работу. Предлагаю общаться на "ты".
#
# При обнаружении у Тебя в работе ошибки, в первый раз я лишь укажу на ее наличие и у Тебя будет возможность самому найти её и исправить. В реальной работе твой начальник будет поступать также, а я пытаюсь подготовить тебя именно к работе аналитиком. Однако если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.
#
# Просьба при доработке работы оставлять мои комментарии без изменений.
#
# Комментарии я разделяю на следующие категории:
#
# <div class="alert alert-block alert-success">
# В случае если всё верно!
# </div>
#
#
# <div class="alert alert-block alert-warning">
# В случае если можно что-то доработать, но эта доработка не критична или если есть варианты улучшения работы.
# </div>
#
# <div class="alert alert-block alert-danger">
# Замечания, которые нужно исправить. Без исправления этих замечаний проект принят не может быть.
# </div>
#
# ### <font color='blue'>Резензия на работу v. 1</font> <a class="tocSkip">
# * В целом у Тебя хорошая работа, но требуются доработки.
# * Успехов!
#
# ### <font color='blue'>Резензия на работу v. 2</font> <a class="tocSkip">
# * Осталась буквальна одна доработка :)
# * Жду исправленную работу!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Я так понимаю, это комментарий к расчёту sMAPE, тогда добавил.
# </div>

# %% [markdown]
# ### <font color='blue'>Резензия на работу v. 3</font> <a class="tocSkip">
# * Поздравляю проект зачтён :)
# * Успехов на следующем спринте!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span></li><li><span><a href="#Обучение-разных-моделей" data-toc-modified-id="Обучение-разных-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение разных моделей</a></span></li><li><span><a href="#Проверим-на-тестовой-выборке" data-toc-modified-id="Проверим-на-тестовой-выборке-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверим на тестовой выборке</a></span></li><li><span><a href="#Сравним-нашу-модель-с-константным-подходом" data-toc-modified-id="Сравним-нашу-модель-с-константным-подходом-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Сравним нашу модель с константным подходом</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Комментарий ревьюера v. 1:
#
# Отлично, проект описан, но сформулируй, пожалуйста, его цель.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Светлана, добрый день! Прежде всего, хочу поблагодарить тебя за трудоёмкую работу по оценке замечаний. В целом, проект сложный и глаз замыливается при таком объёме работ. Я постарался ответить на каждое замечание красного и жёлтого цвета. Что касается вступления, оно было написано до меня и я думал, что это уже предустановленное описание. Также прошу прощения, не увидел пример, как мне лучше оформлять комментарии, оформил из того, что есть (жёлтым). Спасибо.
# </div>

# %% [markdown]
# Задачи и цели проекта:
#
# 1. Подготовьте данные
# 1.1. Откройте файлы и изучите их.
# Путь к файлам:
# /datasets/gold_recovery_train_new.csv. Скачать датасет
# /datasets/gold_recovery_test_new.csv. Скачать датасет
# /datasets/gold_recovery_full_new.csv. Скачать датасет
# 1.2. Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.
# 1.3. Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# 1.4. Проведите предобработку данных.
# 2. Проанализируйте данные
# 2.1. Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.
# 2.2. Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# 2.3. Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# 3. Постройте модель
# 3.1. Напишите функцию для вычисления итоговой sMAPE.
# 3.2. Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 3:
#
# Ок :)
# </div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Прочитали проект, вздохнули, импортировали все библиотеки и поехали дальше:

# %%
import pandas as pd
#from pandas_profiling import ProfileReport
import numpy as np

from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)

from IPython.display import display, HTML, Image
#from ipywidgets import GridspecLayout

import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Если ты, добрый человек, проверяешь это на своём ноутбуке, то вот тебе полные пути:

# %%
train_df = pd.read_csv("https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv") 
test_df = pd.read_csv("https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv")
full_df = pd.read_csv("https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv")

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Отлично, данные загружены.
# </div>

# %%
full_df.head(2) # и, пожалуйста, не требуйте sample
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
#
# ...

# %% [markdown]
# Если бы удалось включить ProfileReport, можно было бы увидеть множество пропущенных значений, нулей, а также скошенных распределений:

# %%
#display(ProfileReport(full_df, 
#                            title="Исходные данные", 
#                            explorative=True, 
#                            html={'style':{'full_width':True}}, 
#                            minimal=True))

# %% [markdown]
# Создадим функцию для расчёта recovery:

# %%
def recovery(C, F, T):
    
    numerator = (C*(F-T))
    divider =(F*(C-T))
    
    rec = (numerator / divider) * 100
    
    # я читал, лучше заполнить значения меньше нуля и больше ста
    rec[rec<0] = np.nan
    rec[rec>100] = np.nan
    return rec

# %% [markdown]
# Применим функцию:

# %%
t,f,c = full_df['rougher.output.tail_au'], full_df['rougher.input.feed_au'], full_df['rougher.output.concentrate_au']
rec = recovery(c, f, t)
print("Совпадающих значений:", sum(abs(full_df['rougher.output.recovery'] - rec) < 10**(-4)))
print("Среднее:", rec.mean())
print("MAE:", mean_absolute_error(full_df['rougher.output.recovery'].dropna(),
                                                                  rec.dropna()))
print("--------------------------")
print("Пропуски в расчете:", rec.isna().sum())
print("Пропуски в full DataFrame:", full_df['rougher.output.recovery'].isna().sum())
# Out:
# Совпадающих значений: 19439
# Среднее: 83.3285873508393
# MAE: 9.678490154319586e-15
# --------------------------
# Пропуски в расчете: 0
# Пропуски в full DataFrame: 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# А какой можно сделать вывод из полученного значения MAE?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Наша задача - спрогнозировать коэффициент восстановления золота из золотосодержащей руды. В описании значится: "Найдите MAE между вашими расчётами и значением признака. Опишите выводы.". Средняя абсолютная ошибка (MAE) - это один из способов сравнения прогнозов с их окончательными результатами, иными словами, является мерой ошибки между парными наблюдениями, выражающими одно и то же явление. Так как у нас средняя абсолютная ошибка достаточно мала, считаем, что recovery посчитан верно.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Да, мы можем сделать вывод, что расчёт правильный.
# </div>

# %% [markdown]
# И посмотрим на отсутствующие столбцы:

# %%
missing_columns = list(set(train_df.columns) - set(test_df.columns))
missing_columns
# Out:
# ['rougher.output.concentrate_ag',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'final.output.recovery',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.tail_pb',
#  'final.output.concentrate_ag',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_sol',
#  'rougher.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'secondary_cleaner.output.tail_sol',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'secondary_cleaner.output.tail_au',
#  'rougher.output.tail_pb',
#  'final.output.tail_ag',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'final.output.tail_pb',
#  'primary_cleaner.output.tail_au',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.tail_sol',
#  'rougher.output.tail_au',
#  'rougher.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# В тесте у нас нет признаков output, так как это целевые признаки. Аналогично, в тесте нет признаков calculation для этапа rougher, видимо, эти данные рассчитываются позднее и не доступны во время процесса.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Отлично, отсутствующие признаки выявлены.
# </div>

# %% [markdown]
# Осуществим предобработку данных:

# %%
datasets = [train_df, test_df, full_df]

# %%
for dataset in datasets:
    print("Кортеж:", dataset.shape)
    print("NA'нов", dataset.isna().sum().sum())
    print("Дубликатов:", dataset.duplicated().sum())
    print("--------------------------------------")
    dataset["date"] = pd.to_datetime(dataset["date"])
# Out:
# Кортеж: (14149, 87)
# NA'нов 4100
# Дубликатов: 0
# --------------------------------------
# Кортеж: (5290, 53)
# NA'нов 90
# Дубликатов: 0
# --------------------------------------
# Кортеж: (19439, 87)
# NA'нов 4481
# Дубликатов: 0
# --------------------------------------

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Да, дубликатов у нас нет.
# </div>

# %%
rec.isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Пропусков тоже нет.
# </div>

# %% [markdown]
# Дополнительно можно посмотреть на пропуски в данных в трейне и тесте:

# %%
def show_na(df):
    na_info = (df.isna() | df.isnull()).sum()
    res = (pd.concat([na_info / df.shape[0], na_info], axis=1,  keys=['percent', 'abs'])
           .sort_values('percent', ascending=False))
    return res

# %%
show_na(train_df).head(10)
# Out:
#                                            percent   abs
# secondary_cleaner.output.tail_sol         0.113436  1605
# rougher.state.floatbank10_e_air           0.030815   436
# rougher.input.floatbank11_xanthate        0.030249   428
# primary_cleaner.output.concentrate_sol    0.020213   286
# secondary_cleaner.state.floatbank2_a_air  0.015337   217
# final.output.concentrate_sol              0.014913   211
# rougher.input.feed_size                   0.010177   144
# primary_cleaner.input.xanthate            0.007068   100
# rougher.input.feed_pb                     0.007068   100
# final.output.tail_pb                      0.007068   100

# %%
show_na(test_df).head(10)
# Out:
#                                            percent  abs
# rougher.input.floatbank11_xanthate        0.004726   25
# rougher.input.feed_sol                    0.003970   21
# secondary_cleaner.state.floatbank3_a_air  0.001701    9
# rougher.input.floatbank11_sulfate         0.001512    8
# primary_cleaner.input.depressant          0.000945    5
# rougher.input.floatbank10_sulfate         0.000945    5
# primary_cleaner.input.xanthate            0.000756    4
# primary_cleaner.input.sulfate             0.000756    4
# rougher.input.feed_rate                   0.000567    3
# secondary_cleaner.state.floatbank2_a_air  0.000567    3

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Процент пропусков расчитан. Это важная информация для принятия решения по обработке пропусков.
# </div>

# %% [markdown]
# Пропуски в тесте незначительны, более значительны в трейне, в целевых признаках .output., также в rougher.output.recovery. Пока не будем обрабатывать пропуски, а при машинном обучении на кросс-валидации проверим, какой способ заполнения или удаления пропусков покажет себя лучше.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Пропуски в тесте лучше удалить, т. к. обучение на синтетических данных в целевом признаке не самая лучшая идея. А вот пропуски в нецелевых признаках лучше заполнить. Здесь можно воспользоваться тем, что "Соседние по времени параметры часто похожи." Т. е. нужно воспользоваться методом ffill, который позволяет заполнить пропуски предыдущими значениями. Такой подход связан с тем, что концентрация не может резко меняться, т. е. соседние по времени/расположению точки будут иметь близкие значения концентрации вещества. Подробнее: https://www.geeksforgeeks.org/python-pandas-dataframe-ffill/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Наверное, я что-то не понял. Я уже использовал ffil в проекте ниже, очень хороший метод, а здесь применил ниже, хотя не очень понимаю смысл (стратегии удаления и заполнения стало использовать бессмысленно, так как результат будет одинаковым). Подсказать в чате мне никто толком не смог:
# </div>

# %%
#test_df.dropna(inplace=True)
#train_df.fillna(method='ffill', inplace=True)
# Уберём это недоразумение и станет всё ясно.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Ок, прости, в описании было упомянуто только "Пока не будем обрабатывать пропуски", поэтому я и добавила комментарий.
#
# Описание Твоих действий и код должны соответствовать друг другу.
# </div>

# %%
show_na(test_df).head(2)
# Out:
#                                      percent  abs
# rougher.input.floatbank11_xanthate  0.004726   25
# rougher.input.feed_sol              0.003970   21

# %%
show_na(train_df).head(2)
# Out:
#                                     percent   abs
# secondary_cleaner.output.tail_sol  0.113436  1605
# rougher.state.floatbank10_e_air    0.030815   436

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# Построим распределения концентраций металов на выходе каждого процесса и в хвостах:

# %%
process = ['rougher.input.feed',
           'rougher.output.concentrate',
           'primary_cleaner.output.concentrate',
           'final.output.concentrate']

process_tail = ['rougher.input.feed',
                'rougher.output.tail',
                'primary_cleaner.output.tail',
                'final.output.tail']

metals = ['au', 'ag', 'pb']

fig, axs = plt.subplots(1, len(process), figsize=(20, 6), constrained_layout=True)
fig.suptitle('Концентрации металлов в выпуске по стадиям', fontsize=24)

for stage, ax in zip(process, axs):
    ax.set_title(stage)
    for metal in metals:        
        cols = train_df.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(train_df.loc[:, cols].dropna(), label=metal, ax=ax)    
plt.legend()

fig, axs = plt.subplots(1, 4, figsize=(20, 6), constrained_layout=True)
fig.suptitle('Концентрации металлов в хвосте по стадиям', fontsize=24)

for stage, ax in zip(process_tail, axs):
    ax.set_title(stage)
    for metal in metals:        
        cols = train_df.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(train_df.loc[:, cols].dropna(), label=metal, ax=ax)
plt.legend()

plt.show()

# %% [markdown]
# Из графиков видно, что в процессе очистики концентрация золота возрастает (логично).
# Концентрация металлов в хвостовых отвалах разная.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# На графиках видны аномалии - близкие к нулю значения концентраций. Как Ты думаешь с чем они могут быть связаны и нужно ли их удалять?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Я считаю, в данном случае нулевые значений необходимы, чтобы модель могла улавливать нулевую концентрацию вещества.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Комментарий ревьюера v. 2:
#
# Значения концентраций близкие к нулю могут быть связаны с сбоями в работе датчиков фиксирующих значений концентраций или сбоями в технологическом процессе.
# </div>

# %% [markdown]
# Я хочу построить графики для концентрации каждого металла на разных процессах на выходе и в хвосте:

# %%
fig, axs = plt.subplots(1, len(metals), figsize=(20, 6), constrained_layout=True)
fig.suptitle('Концентрации металлов в выпуске', fontsize=24)

for metal, ax in zip(metals, axs):
    ax.set_title(metal)
    for stage in process:
        cols = train_df.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(train_df.loc[:, cols].dropna(), label=stage, ax=ax)   
plt.legend()

fig, axs = plt.subplots(1, len(metals), figsize=(20, 6), constrained_layout=True)
fig.suptitle('Концентрации металлов в хвосте', fontsize=24)

for metal, ax in zip(metals, axs):
    ax.set_title(metal)
    for stage in process_tail:
        cols = train_df.columns.str.contains(stage+'_'+metal)
        sns_ax = sns.distplot(train_df.loc[:, cols].dropna(), label=stage, ax=ax)   
plt.legend()

plt.show()

# %% [markdown]
# Видно, что концентрация золота по мере очистки значительно вырастает, также вырастают концентрации серебра и свинца, но не так значительно. В общем и целом - самая большая концентрация металла в хвостах после флотации.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Превосходные графики :) Изменения концентрации золотоа, среребра и свинца проанализированы.

# %% [markdown]
# На всякий случай проверим размер гранул сырья в трейне и в тесте:

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Комментарий ревьюера v. 1:
#
# Please note that you can avoid "<matplotlib.legend.Legend at 0x7f2af05ef8d0>" by using ";" after code lines with graph.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Не понял, что это, у меня всё работает без ошибок (прямо тут).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Комментарий ревьюера v. 2:
#
# Да, ошибок нет, но лучше убрать вывод строки "<matplotlib.legend.Legend at 0x7f50936b6b90>" перед графиком.
# </div>

# %%
sns.distplot(train_df['rougher.input.feed_size'].dropna(), label='train')
sns.distplot(test_df['rougher.input.feed_size'].dropna(), label='test')
plt.legend()

# %% [markdown]
# Как мы видим, распределения очень похожи.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Отлично, распределения размеров частиц в train и test построены и проанализированы. Однако, нужно ещё рассчитать средний размер частиц для train и test и сравнить полученные значения.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Да, ок. См. ниже, ещё раз можно увидеть на графике, что распределения несильно отличаются, но теперь ещё можно посмотреть, что средние размеры (55 и 60) отличаются несильно.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Да, верно размер частиц различается незначительно. Поэтому исходя из этого и того что формы распределений размера частиц похожи можно сделать вывод что  обучающая и тестовая выборки схожи.
# </div>

# %%
x0 = train_df['rougher.input.feed_size']
x1 = test_df['rougher.input.feed_size']

fig = go.Figure()
fig.add_trace(go.Histogram(x=x0, name="train"))
fig.add_trace(go.Histogram(x=x1, name="test"))

fig.update_layout(
    title_text='Распределения размера',
    xaxis_title_text='Value',
    yaxis_title_text='Count',
    bargap=0,
    bargroupgap=0.1
)

fig.show()
# Out:
# <div>
#
#
#             <div id="e7d51897-6908-4e10-b4e9-2bdd762da071" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7d51897-6908-4e10-b4e9-2bdd762da071")) {
#                     Plotly.newPlot(
#                         'e7d51897-6908-4e10-b4e9-2bdd762da071',
# ...

# %% [markdown]
# Теперь согласно задания исследуем суммарно концентрацию в разных процессах в трейне и в тесте.

# %%
fig, axs = plt.subplots(1, len(process), figsize=(20, 6), constrained_layout=True)
fig.suptitle('Сводная информация о концентрациях металлов', fontsize=24)

for stage, ax in zip(process, axs):
    ax.set_title(stage)
    sum_train = train_df[stage+ '_ag'] + train_df[stage+ '_au'] + train_df[stage+ '_pb']
    try:
        sum_test = test_df[stage+ '_ag'] + test_df[stage+ '_au'] + test_df[stage+ '_pb']
        sns.distplot(sum_test.dropna(), label='test', ax=ax) 
    except KeyError:
        pass
    sns.distplot(sum_train.dropna(), label='train', ax=ax) 

plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# 👍👍👍
# </div>

# %% [markdown]
# ## Модель

# %% [markdown]
# Функция для расчета sMAPE
#
# $$ sMAPE = \frac{1}{N} \sum_{i=1}^{N} \frac{|y_i - \hat{y_i}|}{(|y_i| + |\hat{y_i}|) / 2} × 100% $$
# где:
#
# $y_i$ — значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество
# $\hat{y_i}$ — значение предсказания для объекта с порядковым номером i, например, в тестовой выборке
# N — количество объектов в выборке
# $\sum_{i=1}^{N}$ — суммирование по всем объектам выборки (i меняется от 1 до N).

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Ок :)
# </div>

# %%
def smape(target, predictions):
    numerator = abs(predictions - target)
    divider = (abs(target) + abs(predictions)) / 2
    summa = (numerator / divider).sum()

    smape = (1 / len(target)) * summa * 100
    return smape

# %% [markdown]
# Итоговая метрика качества sMAPE final складывается из двух величин:
#
# $$ final   sMAPE = 0.25 × sMAPE(rougher) + 0.75 × sMAPE(final)$$

# %%
def smapefinal(rougher, final):
    smape_final_1 = 0.25 * rougher + 0.75 * final
    return smape_final_1

# %% [markdown]
# ## Обучение разных моделей

# %% [markdown]
# Удалим отсутствующие столбцы из train'a:

# %%
train_df.drop(missing_columns, axis=1, inplace=True)

# %% [markdown]
# Создадим различные функции, для удобства их функционал описал в комментариях:

# %%
def make_copies(train, test, full):
    
    """
    Делаем копию данных
    """
    
    train_copy = train.copy(deep=True)
    test_copy = test.copy(deep=True)
    full_copy = full.copy(deep=True)
    
    return train_copy, test_copy, full_copy


def add_target(train, test, full):
    
    """
    Добавление target из full в train и test
    """
        
    # Добавим target из full_df в train dataset
    train = train.merge(full[['date', 'rougher.output.recovery', 'final.output.recovery']], 
                           how = 'left', on = 'date')
    # Добавим target из full_df в test dataset
    test = test.merge(full[['date', 'rougher.output.recovery', 'final.output.recovery']], 
                           how = 'left', on = 'date')
    return train, test

    
def delete_na(train, test, full):
    
    """
    Удалим значения na из data
    """
    
    train.dropna(inplace=True)
    test.dropna(inplace=True)
    full.dropna(inplace=True)

    return train, test, full


def fill_previous(train, test, full_data):
    
    """
    Добавим na в предыдущие значения
    """
    
    full_data.fillna(method='ffill', inplace=True)
    train.fillna(method='ffill', inplace=True)
    test.fillna(method='ffill', inplace=True)

    return train, test, full_data


def features_target_split(train, test):
    
    """
    Разделим target и test в features и targets
    """
    
    # train выборка
    target_train = train[['rougher.output.recovery', 'final.output.recovery']]
    features_train = train.drop(['rougher.output.recovery', 'final.output.recovery', 'date'], axis=1)

    # test выборка
    target_test = test[['rougher.output.recovery','final.output.recovery']]
    features_test = test.drop(['rougher.output.recovery', 'final.output.recovery', 'date'], axis=1)
    
    return features_train, target_train, features_test, target_test


def scale_minmax(features_train, features_test):
    
    """
    Скалируем данные
    """
    
    scaler = MinMaxScaler()
    cols_train = features_train.columns
    cols_test = features_test.columns
    
    features_train_scaled = pd.DataFrame(scaler.fit_transform(features_train[cols_train]))
    features_test_scaled = pd.DataFrame(scaler.transform(features_test[cols_test]))
    
    return features_train_scaled, features_test_scaled

# %%
def copy_and_add_target(train, test, full):
    
    """
    Создадим копии данных
    """
    
    train_copy, test_copy, full_copy = make_copies(train, test, full)
    train, test = add_target(train_copy, test_copy, full_copy)
    
    return train, test, full_copy


def features_and_scaling(train, test, full):
    
    """
    Разделим и скалируем данные
    """
    
    features_train, target_train, features_test, target_test = features_target_split(train, test)
    features_train, features_test = scale_minmax(features_train, features_test)
    
    return features_train, target_train, features_test, target_test

# %%
def pipeline_with_ffill(train, test, full):
    
    """
    pipeline с заполненными na
    """
    
    train, test, full = copy_and_add_target(train, test, full)
    train, test, full = fill_previous(train, test, full)
    features_train, target_train, features_test, target_test = features_and_scaling(train, test, full)
    
    return features_train, target_train, features_test, target_test


def pipeline_with_drop_na(train, test, full):
    
    """
    pipeline с удалёнными na
    """
    
    train, test, full = copy_and_add_target(train, test, full)
    train, test, full = delete_na(train, test, full)
    features_train, target_train, features_test, target_test = features_and_scaling(train, test, full)
    
    return features_train, target_train, features_test, target_test

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Молодец, что используешь docstrings. Дополнительные материалы: https://www.python.org/dev/peps/pep-0008/
# </div>

# %%
def grid_search_cv(features, target):
    
    model_and_parameters = [
                            #Model
                            (Lasso(random_state=241), 
                                     # params
                                     {'alpha' : np.linspace(-3, 1, 10)}),
                            #Model
                            (Ridge(random_state=241), 
                                     # params
                                     {'alpha' : np.linspace(-3, 1, 10)}),
                            #Model
                            (LinearRegression(),
                                     # params
                                     {})
                                    # Model
#                            (RandomForestRegressor(random_state=241),
                                     # params
#                                    {'n_estimators' : [i for i in range(50,150,10)],
#                                     'max_depth' : [i for i in range(10,40,5)]})
                            ]
    
    best_final_smape = 1000

    for model, params in model_and_parameters:

        scorer = make_scorer(smape, greater_is_better=False)
        grid_rougher = GridSearchCV(estimator=model, param_grid=params, cv=5, scoring=scorer, n_jobs=-1)
        grid_final = GridSearchCV(estimator=model, param_grid=params, cv=5, scoring=scorer, n_jobs=-1)

        grid_rougher.fit(features, target["rougher.output.recovery"])
        rougher_smape = grid_rougher.best_score_

        grid_final.fit(features, target["final.output.recovery"])
        final_smape = grid_final.best_score_

        weighted_final_smape = smapefinal(rougher_smape, final_smape)

        if weighted_final_smape < best_final_smape:
            best_model_rougher = grid_rougher.best_estimator_
            best_model_final = grid_final.best_estimator_
            best_final_smape = weighted_final_smape

        print(model.__class__.__name__, ":", weighted_final_smape)
        
    return best_model_rougher, best_model_final

# %% [markdown]
# <b>Стратегия удаления пропусков</b>

# %%
features_train_scaled_dropped, target_train_dropped, \
        features_test_scaled_dropped, target_test_dropped = pipeline_with_drop_na(train_df, test_df, full_df)

# %%
print("Train features length:", len(features_train_scaled_dropped))
print("Train target length:", len(target_train_dropped))
print("----------------------------")
print("Test features length:", len(features_test_scaled_dropped))
print("Test target length:", len(target_test_dropped))
# Out:
# Train features length: 12679
# Train target length: 12679
# ----------------------------
# Test features length: 5229
# Test target length: 5229

# %%
best_model_rougher_drop_na, best_model_final_drop_na = grid_search_cv(features_train_scaled_dropped, target_train_dropped)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Добавь, пожалуйста, описание к моделям (используемые гиперпараметры, значения метрик и т. д.). Просьба учесть этот комментарий для всех моделей.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Подскажи пожалуйста, описание чего надо добавить, хотя бы к каким методам, поскольку вроде всё стандартно, я ими пользовался и в предыдущем проекте. Если estimator, param_grid, cv, scoring, n_jobs, так это классика, она многократно использована ранее и описана тут https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
# Просто хочу понять, что именно критично для выполнения данного проекта.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 2:
#
# Привожу пример описания:
#
# "В случае модели Lasso варьировали параметр alpha в диапазоне ... Удалось достигнуть ... значения метрики sMAPE. и т. д."
#
# Дополнительно можно оценить время обучения и предсказаний модели, а также проанализировать склонна ли модель к переобучению.
#
# Это требование связано с тем, что текстовое описание должно быть достаточным для понимания того какие модели построили и какие результаты получили.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Дополнительные материалы: https://elitedatascience.com/overfitting-in-machine-learning, https://www.analyticsvidhya.com/blog/2015/02/avoid-over-fitting-regularization/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента 2:</b>
# А, получается, не в коде расписать, что использовал, а как бы в выводе?
# Я решил проверить две стратегии - стратегию удаления пропусков и стратегию заполнения пропусков. И в том и другом случае я использовал функцию grid_search_cv, с параметрами для каждой модели Lasso, Ridge, LinearRegression. random_state - это генератор псевдослучайных чисел, а в моделях Lasso и Ridge я использовал alpha с одинаковыми значениями np.linspace от -3, 1, 10 до 0.1, 3, 20, благодаря чему удалось достичь значения метрики sMAPE 9.42 (в отличие от 9.44).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 3:
#
# Да, как правило текст в коде воспринимается как комментарий к коду, а не описание используемых методов и анализ результатов. Поэтому нужно добавлять описание в ячейках markdown.
# </div>

# %% [markdown]
# <b>Стратегия заполнения пропусков</b>

# %%
features_train_scaled_ffilled, target_train_ffilled, \
        features_test_scaled_ffilled, target_test_ffilled = pipeline_with_ffill(train_df, test_df, full_df)

# %%
print("Train features length:", len(features_train_scaled_ffilled))
# здесь и далее непереводимая для простого смертного игра слов
print("Train target length:", len(target_train_ffilled))
print("----------------------------")
print("Test featrues length:", len(features_test_scaled_ffilled))
print("Test target length:", len(target_test_ffilled))

# %%
best_model_rougher_ffilled, best_model_final_ffilled = grid_search_cv(features_train_scaled_ffilled, target_train_ffilled)

# %% [markdown]
# <b>Вывод. Лучше всего себя показывает стратегия удаления пропусков, наилучшая модель - Lasso. Я использовал для проверки двух стратегий функцию grid_search_cv, с параметрами для каждой модели Lasso, Ridge, LinearRegression. random_state - это генератор псевдослучайных чисел, а в моделях Lasso и Ridge я использовал alpha с одинаковыми значениями np.linspace от -3, 1, 10 до 0.1, 3, 20, благодаря чему удалось достичь значения метрики sMAPE 9.42 (в отличие от 9.44).</b>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Предлагаю заполнить пропуски с помощью метода ffill.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Вроде же я как раз и заполнил выше, или я что-то не понимаю? Кстати теперь разные стратегии использовать бессмысленно, так как пропуски и так были удалены и, как видно выше, все показатели одинаковы.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Ок :)
# </div>

# %% [markdown]
# ## Проверим на тестовой выборке

# %%
preds_rough = best_model_rougher_drop_na.predict(features_test_scaled_dropped)
preds_final = best_model_final_drop_na.predict(features_test_scaled_dropped)
#smapefinal(smape(preds_rough, target_test_dropped["rougher.output.recovery"]), 
#           smape(preds_final, target_test_dropped["final.output.recovery"]))
print("Тестовая выборка: {:.2f}".format(smapefinal(smape(preds_rough, target_test_dropped["rougher.output.recovery"]), 
           smape(preds_final, target_test_dropped["final.output.recovery"]))))

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Комментарий ревьюера v. 1:
#
# Форматировать вывод данных можно с помощью .format(). Подробнее: https://pyformat.info/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Да не вопрос, я его и так везде использую, просто меня он очень раздражает. Поправил.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Ок, так просто на мой взгляд вывод данных смотрится намного лучше :)
# </div>

# %% [markdown]
# ## Сравним нашу модель с константным подходом

# %%
dmb_mean = DummyRegressor(strategy="mean")

# %%
dmb_mean.fit(features_train_scaled_dropped, target_train_dropped["rougher.output.recovery"])
preds_rough = dmb_mean.predict(features_test_scaled_dropped)
dmb_mean.fit(features_train_scaled_dropped, target_train_dropped["final.output.recovery"])
preds_final = dmb_mean.predict(features_test_scaled_dropped)
print("Константный подход: {:.2f}".format(smapefinal(smape(preds_rough, target_test_dropped["rougher.output.recovery"]), 
           smape(preds_final, target_test_dropped["final.output.recovery"]))))

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Комментарий ревьюера v. 1:
#
# Рекомендую добавить таблицу с результатами обучения и тестирования моделей (модель, гиперпараметры, значение метрики, время обучения и предсказаний).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# А я, как оказалось, и не знаю, как сюда добавлять таблицы, хотя видел в рассматриваемых проектах. Поэтому сюда дошёл, ни разу их не применив. )
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 2:
#
# Нужно просто создать датафрейм и заполнить его результатами анализа моделей.
#
# Высылаю шаблон для такой таблицы:
#
# d = ({'sMAPE флотации (%)':[smape_lr_rougher,grid_search_r.best_score_,smape_las_rougher]
#       ,'sMAPE очистки (%)':[smape_lr_final,grid_search_f.best_score_,smape_las_final]
#       ,'sMAPE итоговое (%)':[smape_f_lr, smape_f_rf,smape_f_las]
#      ,'sMAPE флотации на тестовой выборке (%)':[np.nan, np.nan, smape_test_r]
#       ,'sMAPE очистки на тестовой выборке (%)':[np.nan, np.nan, smape_test_f]
#       ,'sMAPE итоговое на тестовой выборке (%)':[np.nan, np.nan,smape_test_fin]})
# df = pd.DataFrame(data=d, index=['LinearRegression','RandomForest','Lasso',])
# df
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Дополнительные материалы: https://milkandhoney.ai/insights/best-practice-approach-to-machine-learning-model-development
# </div>

# %% [markdown]
# # Вывод

# %% [markdown]
# 1. Мы произвели исследовательский анализ данных, проверили наличие пропусков, дубликатов. В тестовой выборке не оказалось признаков, которые обозначают характеристики смеси на разных этапах обработки.
# 2. Обнаружили, что концентрация металлов увеличивается с каждым этапом.
# 3. Распределения размеров гранул в train и test выборках одинаковы.
# 4. Суммарные распределения концентрации имеют множество нулевых значений.
# 5. Наилучшей стратегией работы с пропусками оказалась удаление пропущенных строк.
# 6. Наилучшая модель - Lasso, со значением метрики smape 9.4, что лучше, чем у константной модели.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Отлично, итог анализа подведён. 👍👍👍
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
